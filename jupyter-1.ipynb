# %% [markdown]
# # This is a notebook
#
# ## Section one
#
# some **bold** text

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Let us make a plot

# %%
x = np.linspace(0, 50, 100)
x *= np.cos(x)

pd.DataFrame({'x': x}).plot()
# Out:
# <AxesSubplot:>
